# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras

# %%
df = pd.read_csv('telco_customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID', axis=1, inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
pd.to_numeric(df['TotalCharges'], errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df['TotalCharges'], errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df1 = df[df['TotalCharges']!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
pd.to_numeric(df1['TotalCharges'])
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])
df1.TotalCharges.dtypes
# Out:
# <ipython-input-21-b0b89a991a12>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])
# dtype('float64')

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 1                   No             DSL                  Yes
# 3     No phone service             DSL                  Yes
# 6                  Yes     Fiber optic                   No
# 7     No phone service             DSL                  Yes
# ...                ...             ...                  ...
# 7037                No              No  No internet service
# 7038               Yes             DSL                  Yes
# 7039               Yes     Fiber optic                   No
# 7040  No phone service             DSL                  Yes
# 7042                No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 3                      No                  Yes                  Yes
# 6                     Yes                   No                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7042                   No                  Yes                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 3                      No                   No        One year
# 6                     Yes                   No  Month-to-month
# 7                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 7037  No internet service  No internet service        Two year
# 7038                  Yes                  Yes        One year
# 7039                  Yes                  Yes        One year
# 7040                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 3                  No  Bank transfer (automatic)           42.30
# 6                 Yes    Credit card (automatic)           89.10
# 7                  No               Mailed check           29.75
# ...               ...                        ...             ...
# 7037              Yes  Bank transfer (automatic)           21.15
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 3          1840.75    No
# 6          1949.40    No
# 7           301.90    No
# ...            ...   ...
# 7037       1419.40    No
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7042       6844.50    No
#
# [5163 rows x 20 columns]

# %%
def visualize_data(feature):
    churn_no = df1[df1.Churn=='No'][feature]
    churn_yes = df1[df1.Churn=='Yes'][feature]
    
    plt.hist([churn_yes, churn_no], color=['green', 'red'], label=['Churn=Yes', 'Churn=No'])
    plt.title('Customer Churn')
    plt.xlabel(feature)
    plt.ylabel('Number of Customers')
    plt.legend()

# %%
visualize_data('tenure')

# %%
visualize_data('MonthlyCharges')

# %%
def print_column_values(df):
    for column in df:
        print('{}: {}'.format(column, df[column].unique()))

# %%
print_column_values(df1)
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: ['No' 'Yes']

# %%
df1.replace('No internet service', 'No', inplace=True)
# Out:
# C:\Users\slcccc\anaconda3\lib\site-packages\pandas\core\frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
print_column_values(df1)
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: ['No' 'Yes']

# %%
df1.replace('No phone service', 'No', inplace=True)
print_column_values(df1)
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: ['No' 'Yes']

# %%
yes_no_columns = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 
                  'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']

for col in yes_no_columns:
    df1[col].replace({'Yes': 1, "No": 0}, inplace=True)
# Out:
# C:\Users\slcccc\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
print_column_values(df1)
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female': 1, "Male": 0}, inplace=True)

# %%
df1['gender'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1.dtypes
# Out:
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService      object
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract             object
# PaperlessBilling      int64
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService', 'Contract', 'PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 4938       0              0        1           1      17             1
# 5289       1              0        0           0      61             1
# 4560       0              0        1           1       9             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4938              0               1             0                 1  ...
# 5289              1               1             1                 1  ...
# 4560              1               0             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 4938                    0                            1                   0
# 5289                    0                            1                   0
# 4560                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 4938                        1                  0                  0
# 5289                        0                  1                  0
# 4560                        0                  1                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 4938                                        0
# 5289                                        0
# 4560                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 4938                                      0                               1
# 5289                                      0                               0
# 4560                                      0                               1
#
#       PaymentMethod_Mailed check
# 4938                           0
# 5289                           1
# 4560                           0
#
# [3 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 4002       0              0        1           1  1.000000             1
# 5057       0              0        0           0  0.112676             1
# 1989       1              0        1           1  0.478873             0
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4002              1               1             1                 1  ...
# 5057              1               0             0                 0  ...
# 1989              0               1             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 4002                    1                            0                   0
# 5057                    0                            1                   0
# 1989                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 4002                        0                  0                  1
# 5057                        1                  0                  0
# 1989                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 4002                                        1
# 5057                                        0
# 1989                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 4002                                      0                               0
# 5057                                      0                               1
# 1989                                      1                               0
#
#       PaymentMethod_Mailed check
# 4002                           0
# 5057                           0
# 1989                           0
#
# [3 rows x 27 columns]

# %%
print_column_values(df2)
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
X = df2.drop('Churn', axis=1)
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=31)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 6764       1              0        0           0  0.000000             1
# 157        0              0        1           1  0.295775             1
# 2413       0              0        1           1  0.084507             0
# 4174       1              0        0           0  0.507042             0
# 1073       0              0        0           0  0.084507             1
# 6267       1              0        0           0  0.000000             1
# 174        1              0        0           0  0.436620             1
# 4097       0              0        0           1  0.887324             1
# 1237       0              0        0           0  0.169014             1
# 5455       1              0        0           0  0.070423             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 6764              0               0             0                 0  ...
# 157               0               0             0                 0  ...
# 2413              0               1             0                 1  ...
# 4174              0               0             0                 0  ...
# 1073              1               0             0                 1  ...
# 6267              0               0             0                 0  ...
# 174               0               0             0                 0  ...
# 4097              0               0             1                 0  ...
# 1237              0               0             0                 0  ...
# 5455              0               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 6764                    0                            1                   0
# 157                     0                            0                   1
# 2413                    1                            0                   0
# 4174                    1                            0                   0
# 1073                    0                            1                   0
# 6267                    0                            1                   0
# 174                     0                            0                   1
# 4097                    0                            1                   0
# 1237                    0                            0                   1
# 5455                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 6764                        1                  0                  0
# 157                         0                  1                  0
# 2413                        0                  0                  1
# 4174                        1                  0                  0
# 1073                        1                  0                  0
# 6267                        1                  0                  0
# 174                         0                  1                  0
# 4097                        1                  0                  0
# 1237                        0                  1                  0
# 5455                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 6764                                        0
# 157                                         0
# 2413                                        0
# 4174                                        0
# 1073                                        1
# 6267                                        0
# 174                                         1
# 4097                                        0
# 1237                                        0
# 5455                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 6764                                      0                               1
# 157                                       0                               0
# 2413                                      1                               0
# 4174                                      1                               0
# 1073                                      0                               0
# 6267                                      0                               1
# 174                                       0                               0
# 4097                                      1                               0
# 1237                                      0                               0
# 5455                                      1                               0
#
#       PaymentMethod_Mailed check
# 6764                           0
# 157                            1
# 2413                           0
# 4174                           0
# 1073                           0
# 6267                           0
# 174                            0
# 4097                           0
# 1237                           1
# 5455                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %%
model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 2s 4ms/step - loss: 0.4917 - accuracy: 0.7588
# Epoch 2/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4313 - accuracy: 0.7902
# Epoch 3/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4228 - accuracy: 0.7979
# Epoch 4/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.8000
# Epoch 5/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4163 - accuracy: 0.7998
# Epoch 6/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4140 - accuracy: 0.8025
# Epoch 7/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4130 - accuracy: 0.8034
# Epoch 8/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4109 - accuracy: 0.8073
# Epoch 9/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 0.8044
# Epoch 10/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4071 - accuracy: 0.8085
# Epoch 11/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4070 - accuracy: 0.8082
# Epoch 12/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4058 - accuracy: 0.8069
# Epoch 13/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4037 - accuracy: 0.8075
# Epoch 14/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.4032 - accuracy: 0.8092
# Epoch 15/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4021 - accuracy: 0.8133
# Epoch 16/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4024 - accuracy: 0.8107
# Epoch 17/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4007 - accuracy: 0.8119
# Epoch 18/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.8116
# Epoch 19/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3995 - accuracy: 0.8126
# Epoch 20/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3988 - accuracy: 0.8098
# Epoch 21/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3984 - accuracy: 0.8089
# Epoch 22/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3976 - accuracy: 0.8140
# Epoch 23/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3969 - accuracy: 0.8096
# Epoch 24/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3961 - accuracy: 0.8132
# Epoch 25/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3965 - accuracy: 0.8128
# Epoch 26/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3949 - accuracy: 0.8140
# Epoch 27/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3949 - accuracy: 0.8126
# Epoch 28/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3939 - accuracy: 0.8130
# Epoch 29/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3940 - accuracy: 0.8146
# Epoch 30/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3926 - accuracy: 0.8167
# Epoch 31/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3929 - accuracy: 0.8133
# Epoch 32/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3927 - accuracy: 0.8139
# Epoch 33/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3919 - accuracy: 0.8162
# Epoch 34/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3903 - accuracy: 0.8148
# Epoch 35/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3906 - accuracy: 0.8160
# Epoch 36/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3903 - accuracy: 0.8132
# Epoch 37/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3895 - accuracy: 0.8156
# Epoch 38/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3883 - accuracy: 0.8171
# Epoch 39/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3884 - accuracy: 0.8139
# Epoch 40/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3874 - accuracy: 0.8169
# Epoch 41/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3870 - accuracy: 0.8176
# Epoch 42/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3864 - accuracy: 0.8160
# Epoch 43/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3872 - accuracy: 0.8171
# Epoch 44/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3867 - accuracy: 0.8155
# Epoch 45/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3852 - accuracy: 0.8149
# Epoch 46/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3853 - accuracy: 0.8174
# Epoch 47/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3839 - accuracy: 0.8192
# Epoch 48/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3843 - accuracy: 0.8188: 0s - loss: 0.3
# Epoch 49/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3827 - accuracy: 0.8188
# Epoch 50/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3833 - accuracy: 0.8176
# Epoch 51/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3833 - accuracy: 0.8199
# Epoch 52/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3815 - accuracy: 0.8167
# Epoch 53/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3818 - accuracy: 0.8183
# Epoch 54/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3813 - accuracy: 0.8183
# Epoch 55/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3811 - accuracy: 0.8183
# Epoch 56/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3800 - accuracy: 0.8183
# Epoch 57/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3796 - accuracy: 0.8197
# Epoch 58/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3792 - accuracy: 0.8197
# Epoch 59/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3788 - accuracy: 0.8178
# Epoch 60/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3780 - accuracy: 0.8190
# Epoch 61/100
# 176/176 [==============================] - 1s 8ms/step - loss: 0.3779 - accuracy: 0.8203
# Epoch 62/100
# 176/176 [==============================] - 1s 7ms/step - loss: 0.3785 - accuracy: 0.8194
# Epoch 63/100
# 176/176 [==============================] - 2s 9ms/step - loss: 0.3767 - accuracy: 0.8203
# Epoch 64/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3775 - accuracy: 0.8208
# Epoch 65/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.3763 - accuracy: 0.8229
# Epoch 66/100
# 176/176 [==============================] - 2s 9ms/step - loss: 0.3767 - accuracy: 0.8204
# Epoch 67/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3758 - accuracy: 0.8187
# Epoch 68/100
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3753 - accuracy: 0.8222
# Epoch 69/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3753 - accuracy: 0.8199: 0s - loss: 0.386
# Epoch 70/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3738 - accuracy: 0.8226
# Epoch 71/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3749 - accuracy: 0.8215
# Epoch 72/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3737 - accuracy: 0.8226
# Epoch 73/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3745 - accuracy: 0.8224
# Epoch 74/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3726 - accuracy: 0.8219
# Epoch 75/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3735 - accuracy: 0.8217
# Epoch 76/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3726 - accuracy: 0.8233
# Epoch 77/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3718 - accuracy: 0.8235
# Epoch 78/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3715 - accuracy: 0.8210
# Epoch 79/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3722 - accuracy: 0.8220
# Epoch 80/100
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3704 - accuracy: 0.8251
# Epoch 81/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3704 - accuracy: 0.8229
# Epoch 82/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3703 - accuracy: 0.8238
# Epoch 83/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3710 - accuracy: 0.8240
# Epoch 84/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3694 - accuracy: 0.8240
# Epoch 85/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3697 - accuracy: 0.8245
# Epoch 86/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3687 - accuracy: 0.8217
# Epoch 87/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3696 - accuracy: 0.8213
# Epoch 88/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3678 - accuracy: 0.8254
# Epoch 89/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8219
# Epoch 90/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3664 - accuracy: 0.8293
# Epoch 91/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3666 - accuracy: 0.8242
# Epoch 92/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3673 - accuracy: 0.8267
# Epoch 93/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3663 - accuracy: 0.8263
# Epoch 94/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3663 - accuracy: 0.8236
# Epoch 95/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3660 - accuracy: 0.8267
# Epoch 96/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3664 - accuracy: 0.8268
# Epoch 97/100
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3658 - accuracy: 0.8261
# Epoch 98/100
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3658 - accuracy: 0.8281
# Epoch 99/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3654 - accuracy: 0.8261
# Epoch 100/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3645 - accuracy: 0.8277

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 1s 8ms/step - loss: 0.4661 - accuracy: 0.7861
# [0.46614891290664673, 0.7860696315765381]

# %%
y_hat = model.predict(X_test)
y_hat[:5]
# Out:
# array([[0.26152194],
#        [0.8415625 ],
#        [0.02579889],
#        [0.49881458],
#        [0.08211541]], dtype=float32)

# %%
y_test[:5]
# Out:
# 674     1
# 4701    0
# 6547    0
# 4451    0
# 871     0
# Name: Churn, dtype: int64

# %%
y_pred = []
for element in y_hat:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 0, 0, 1, 0, 0, 0, 1]

# %%
y_test[:10]
# Out:
# 674     1
# 4701    0
# 6547    0
# 4451    0
# 871     0
# 4851    1
# 6652    0
# 5055    0
# 1060    0
# 4139    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      1036
#            1       0.61      0.54      0.57       371
#
#     accuracy                           0.79      1407
#    macro avg       0.72      0.71      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[907, 129],
#        [172, 199]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize=(12,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(87.0, 0.5, 'Truth')

# %%
round((907+199)/(907+199+172+129), 2)
# Out:
# 0.79

# %% [markdown]
# Precision for Class 0: (True Predicted 0)/(Total Predicted 0)

# %%
907/(907+172)
# Out:
# 0.8405931417979611

# %% [markdown]
# Precision for Class 1: (True Predicted 1)/(Total Predicted 1)

# %%
199/(129+199)
# Out:
# 0.6067073170731707

# %% [markdown]
# Recall for Class 0: (True Predicted 0)/(True 0)

# %%
907/(907+129)
# Out:
# 0.8754826254826255

# %% [markdown]
# Recall for Class 1: (True Predicted 1)/(True 1)

# %%
199/(172+199)
# Out:
# 0.5363881401617251
